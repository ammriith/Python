# %%
#GRAPHICS AND GRAPHICS3D

from graphics.rectangle import rect_area, rect_peri
from graphics.circle import circle_area, circle_peri
from graphics.graphics3D.cuboid import cuboid_volume, cuboid_surf_area
from graphics.graphics3D.sphere import sphere_volume, sphere_surf_area

length = float(input("Enter the length of the rectangle:"))
width = float(input("Enter the width of the rectangle:"))
print("Rectangle area is:",rect_area(length, width))
print("Rectangle perimeter is:",rect_peri(length, width))

radius = float(input("Enter the radius of the circle:"))
print("circle area is:",circle_area(radius))
print("circle perimeter is:", circle_peri(radius))

cuboid_length = float(input("Enter the length of the cuboid:"))
cuboid_width = float(input("Enter the width of the cuboid:"))
cuboid_heigth = float(input("Enter the heigth of the cuboid:"))
print("cuboid volume  is:",cuboid_volume(cuboid_length, cuboid_width, cuboid_heigth))
print("cuboid surface area  is:",cuboid_surf_area(cuboid_length, cuboid_width, cuboid_heigth))

sphere_radius = float(input("Enter the radius of the sphere:"))
print("sphere suraface area is:",sphere_surf_area(radius))
print("sphere volume is:", sphere_surf_area(radius))
# Out:
# Enter the length of the rectangle: 3
# Enter the width of the rectangle: 4
# Rectangle area is: 12.0
# Rectangle perimeter is: 14.0
# Enter the radius of the circle: 5
# circle area is: 78.53981633974483
# circle perimeter is: 31.41592653589793
# Enter the length of the cuboid: 6
# Enter the width of the cuboid: 5
# Enter the heigth of the cuboid: 4
# cuboid volume  is: 120.0
# cuboid surface area  is: 148.0
# Enter the radius of the sphere: 4
# sphere suraface area is: 314.1592653589793
# sphere volume is: 314.1592653589793

# %%
from ksb import rectangle, circle

l = int(input("Enter the length"))
b = int(input("Enter the breadth"))
r = int(input("Enter the radius"))

rec1 = rectangle.rectarea(l, b)
print("Rectangle area is:",rec1)
rec2 = rectangle.rectperi(l, b)
print("Rectangle perimeter is:",rec2)

cir1 = circle.circlearea(r)
print("Circle area is:",cir1)
cir2 = circle.circleperi(r)
print("Circle perimeter is:",cir2)
# Out:
# Enter the length 10
# Enter the breadth 5
# Enter the radius 4
# Rectangle area is: 50
# Rectangle perimeter is: 30
# Circle area is: 50.26548245743669
# Circle perimeter is: 25.132741228718345
